# %%
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen as uo
import logging

# %%
flipkart_url='https://www.flipkart.com/search?q='+'redmi'
flipkart_url
# Out:
# 'https://www.flipkart.com/search?q=redmi'

# %%
urlclient=uo(flipkart_url)
urlclient

# %% [markdown]
# It has given the HTTP clinet request

# %%
flipkart_page=urlclient.read() #reading the entire html code from the webpage
flipkart_page
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.914d0a.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x5
# ...

# %%
flipkart_html=bs(flipkart_page,'html.parser') # parsing the page for readibility
'https://www.flipkart.com/'+'apple-iphone-12-pro-gold-128-gb/p/itma14a108237af5?pid=MOBFWBYZMDJZMHA9&lid=LSTMOBFWBYZMDJZMHA9SVNUXV&marketplace=FLIPKART&q=iphone12pro&store=tyy%2F4io&srno=s_1_8&otracker=AS_QueryStore_OrganicAutoSuggest_1_4_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_4_na_na_na&iid=f147e58c-144d-4d9d-951c-a8199c6ab2f0.MOBFWBYZMDJZMHA9.SEARCH&ssid=cawxdq46s00000001686898794263&qH=712933e6bd68e7b9'
# flipkart_html
# Out:
# 'https://www.flipkart.com/apple-iphone-12-pro-gold-128-gb/p/itma14a108237af5?pid=MOBFWBYZMDJZMHA9&lid=LSTMOBFWBYZMDJZMHA9SVNUXV&marketplace=FLIPKART&q=iphone12pro&store=tyy%2F4io&srno=s_1_8&otracker=AS_QueryStore_OrganicAutoSuggest_1_4_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_4_na_na_na&iid=f147e58c-144d-4d9d-951c-a8199c6ab2f0.MOBFWBYZMDJZMHA9.SEARCH&ssid=cawxdq46s00000001686898794263&qH=712933e6bd68e7b9'

# %%
bigbox=flipkart_html.findAll("div",{"class":"_1AtVbE col-12-12"})
len(bigbox)
# Out:
# 29

# %%
bigbox[2].div.div.div.a
# Out:
# <a class="_1fQZEK" href="/redmi-a1-light-blue-32-gb/p/itmae4738195e03c?pid=MOBGGYBAGFD4H23B&amp;lid=LSTMOBGGYBAGFD4H23BT8EH5A&amp;marketplace=FLIPKART&amp;q=redmi&amp;store=search.flipkart.com&amp;srno=s_1_2&amp;otracker=search&amp;fm=organic&amp;iid=3c5a06a1-e3b2-47ff-8925-538bc3fe7461.MOBGGYBAGFD4H23B.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=0k2lfxlhk00000001686910279372&amp;qH=9b6bf0057c19bd94" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="REDMI A1+ (Light Blue, 32 GB)" class="_396cs4" loading="eager" src="https://rukminim1.flixcart.com/image/312/312/xif0q/mobile/9/j/r/-original-imagjyhyaf7tdxnc.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDkf8"><input class="_30VH1S" readonly="" type="checkbox"/><div class="_24_Dny"></div></label></span><label class="_6Up2sF"><span>Add to Compare</span></label></div></div><div c
# ...

# %%
bigbox[2].div.div.div.a['href']
# Out:
# '/redmi-a1-light-blue-32-gb/p/itmae4738195e03c?pid=MOBGGYBAGFD4H23B&lid=LSTMOBGGYBAGFD4H23BT8EH5A&marketplace=FLIPKART&q=redmi&store=search.flipkart.com&srno=s_1_2&otracker=search&fm=organic&iid=3c5a06a1-e3b2-47ff-8925-538bc3fe7461.MOBGGYBAGFD4H23B.SEARCH&ppt=None&ppn=None&ssid=0k2lfxlhk00000001686910279372&qH=9b6bf0057c19bd94'

# %%
del bigbox[:3]

# %%
product_link='https://www.flipkart.com'+bigbox[3].div.div.div.a['href']
product_req=requests.get(product_link)
product_html=bs(product_req.text,'html.parser')
comment_box=product_comment_html=product_html.findAll('div',{'class':"_16PBlm"})
len(comment_box)
# Out:
# 11

# %%
comment_box[0].div.div.findAll('p',{'class':'_2sc7ZR _2V5EHH'})
# Out:
# [<p class="_2sc7ZR _2V5EHH">Rupam Dhara</p>]

# %%
comment_box[0].div.div.findAll('p',{'class':'_2sc7ZR _2V5EHH'})[0].text
# Out:
# 'Rupam Dhara'

# %%
#to find all the names of the comments opsted by the people
for i in comment_box:
    print(i.div.div.findAll('p',{'class':'_2sc7ZR _2V5EHH'})[0].text) #the entire div is considered
# Out:
# Rupam Dhara
# Mohd ashraf Mohd ashraf Zargar
# Soumadip Mondal
# Kuldeep Singh
# Rahul Dhochak
# Nilesh  Gaidhani
# Flipkart Customer
# Flipkart Customer
# nitish gaurav
# Deepak kumar Shrivastava
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 3
#       1 #to find all the names of the comments opsted by the people
#       2 for i in comment_box:
# ----> 3     print(i.div.div.findAll('p',{'class':'_2sc7ZR _2V5EHH'})[0].text) #the entire div is considered
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
#<div class="_3LWZlK _1BLPMq">5<img src="..." class="_1wB99o"></div>
comment_box[0].div.div.findAll('div',{'class':'_3LWZlK _1BLPMq'})[0].text
# Out:
# '5'

# %%
for i in comment_box:
    print(i.div.div.findAll('div',{'class':'_3LWZlK _1BLPMq'})[0].text) # also be written as div.div.div.div.text
# Out:
# 5
# 5
# 4
# 5
# 5
# 4
# 5
# 5
# 5
# 5
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 2
#       1 for i in comment_box:
# ----> 2     print(i.div.div.findAll('div',{'class':'_3LWZlK _1BLPMq'})[0].text) # also be written as div.div.div.div.text
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
for i in comment_box:
    print(i.div.div.div.p.text)
# Out:
# Fabulous!
# Excellent
# Wonderful
# Simply awesome
# Wonderful
# Good quality product
# Best in the market!
# Highly recommended
# Wonderful
# Brilliant
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 2
#       1 for i in comment_box:
# ----> 2     print(i.div.div.div.p.text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
#<div class="t-ZTKy"><div><div class="">I have been using iPhones for years, but the fast charging and battery on this one is brilliant. Like i always say, iPhone is more of a jewellery than a phone. But this one has some power-packed features and an awesome camera. So if you can afford it, buy it!</div><span class="_1H-bmy"><span>READ MORE</span></span></div></div>
comment_box[0].div.div.findAll('div',{'class':''})[0].div.text
# Out:
# 'Good phone in this price range, battery backup good, camera ok ok, and performance very very good 🔥 I am mi love And very fast delivery Flipkart, thanks'

# %%
for i in comment_box:
    print(i.div.div.findAll('div',{'class':''})[0].div.text)
# Out:
# Good phone in this price range, battery backup good, camera ok ok, and performance very very good 🔥 I am mi love And very fast delivery Flipkart, thanks
# Nice product nice design of phone camera quality is good and also nice phone
# Very nice mobile 🥳😊Performance is very good 😊Camera quality good 😊Good zooming colour boost ✨I love it😘Thank you Flipkart 😇✨
# Good phone very nice working and good performance nice look
# Mobile is best in this price rangeProcessor Qualcomm Snapdragon 680 is really powerful for multitasking and gamingCamera 📷 Night mode is amazing 🤩Battery life is outstanding fabulous performanceReal 6000 MahOverall excellent performance5 star for Flipkart services
# ...
